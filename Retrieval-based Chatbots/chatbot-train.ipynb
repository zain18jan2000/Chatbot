# %%
data = {"intents": [
             {"tag": "greeting",
              "patterns": ["Hello", "How are you?", "Hi there", "Hi", "Whats up"],
              "responses": ["Howdy Partner!", "Hello", "How are you doing?", "Greetings!", "How do you do?"],
             },
             {"tag": "age",
              "patterns": ["how old are you?", "when is your birthday?", "when was you born?"],
              "responses": ["I am 24 years old", "I was born in 1996", "My birthday is July 3rd and I was born in 1996", "03/07/1996"]
             },
             {"tag": "date",
              "patterns": ["what are you doing this weekend?",
"do you want to hang out some time?", "what are your plans for this week"],
              "responses": ["I am available all week", "I don't have any plans", "I am not busy"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "what are you called?", "who are you?"],
              "responses": ["My name is Kippi", "I'm Kippi", "Kippi"]
             },
             {"tag": "goodbye",
              "patterns": [ "bye", "g2g", "see ya", "adios", "cya"],
              "responses": ["It was nice speaking to you", "See you later", "Speak soon!"]
             }
]}

# %%
''' bag of words steps
1 lower case
2 split the text 
3 remove puctuations
4 lemmatization'''
# Out:
# ' bag of words steps\n1 lower case\n2 split the text \n3 remove puctuations\n4 lemmatization'

# %%
import nltk
from nltk.stem import WordNetLemmatizer
import string
# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()
# Each list to create
words = []
classes = []
doc_X = []
doc_y = []
# Loop through all the intents
# tokenize each pattern and append tokens to words, the patterns and
# the associated tag to their associated list
for intent in data["intents"]:
    for pattern in intent["patterns"]:
        tokens = nltk.word_tokenize(pattern)
        words.extend(tokens)
        doc_X.append(pattern)
        doc_y.append(intent["tag"])
    
    # add the tag to the classes if it's not there already 
    if intent["tag"] not in classes:
        classes.append(intent["tag"])
# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))

print(doc_X)
print('')
print(doc_y)
print('')
print(classes)
print('')
print(words)

# %%
import numpy as np 
import random 
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(doc_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
       # mark the index of class that the current pattern is associated
    # to
    output_row = list(out_empty)
    output_row[classes.index(doc_y[idx])] = 1
    # add the one hot encoded BoW and associated classes to training 
    training.append([bow, output_row])
random.shuffle(training)    
training = np.array(training , dtype = object)
train_y = np.array(list(training[:,1]))
train_x = np.array(list(training[:,0]))
    
print(train_y.shape)    
print(train_X.shape)
# Out:
# (19, 5)
# (19, 39)

# %%
import tensorflow as tf 
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
input_shape = (len(train_X[0]),)
output_shape = len(train_y[0])
epochs = 200
# the deep learning model
model = Sequential()
model.add(Dense(128, input_shape=input_shape, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(output_shape, activation = "softmax"))
adam = tf.keras.optimizers.Adam(learning_rate=0.01, decay=1e-6)
model.compile(loss='categorical_crossentropy',
              optimizer=adam,
              metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_y, epochs=200, verbose=1)
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_28 (Dense)             (None, 128)               5120
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_29 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_30 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 13,701
# Trainable params: 13,701
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 0s 404ms/step - loss: 1.7075 - accuracy: 0.0526
# Epoch 2/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6362 - accuracy: 0.2105
# Epoch 3/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3955 - accuracy: 0.4211
# Epoch 4/200
# 1/1 [==============================] - 0s 4ms/step - loss: 1.3253 - accuracy: 0.5789
# Epoch 5/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2945 - accuracy: 0.7368
# Epoch 6/200
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1084 - accuracy: 0.7895
# Epoch 7/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.1279 - accuracy: 0.6842
# Epoch 8/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0374 - accuracy: 0.7895
# Epoch 9/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8789 - accuracy: 0.7368
# Epoch 10/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.8487 - accuracy: 0.7895
# Epoch 11/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.7501 - accuracy: 0.8421
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5991 - accuracy: 0.8947
# Epoch 13/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4669 - accuracy: 1.0000
# Epoch 14/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3345 - accuracy: 0.9474
# Epoch 15/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3098 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3174 - accuracy: 0.9474
# Epoch 17/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.3290 - accuracy: 0.9474
# Epoch 18/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.3923 - accuracy: 0.8947
# Epoch 19/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 1.0000
# Epoch 20/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1349 - accuracy: 0.9474
# Epoch 21/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1787 - accuracy: 0.9474
# Epoch 22/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0859 - accuracy: 0.9474
# Epoch 23/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0351 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0445 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2562 - accuracy: 0.8947
# Epoch 28/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0432 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0845 - accuracy: 0.9474
# Epoch 31/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0246 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0141 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.9474
# Epoch 34/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0382 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0548 - accuracy: 0.9474
# Epoch 41/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 59/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0564e-04 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.1350e-04 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.2795e-04 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9474
# Epoch 76/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8278e-04 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.2264e-04 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7557e-04 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0008e-04 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.7020e-04 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1562e-04 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8374e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 4ms/step - loss: 5.7510e-04 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.3897e-04 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.9209e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 3ms/step - loss: 8.2262e-05 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3783e-04 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.6343e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.5296e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.9811e-04 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4349e-04 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1977e-05 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.7780e-05 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.0011e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2587e-04 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7397e-04 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4274e-04 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1092e-04 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.4281e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.6632e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4845e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9613e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6494e-05 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.1780e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0597e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.0416e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5251e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.3671e-04 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 4ms/step - loss: 8.6533e-05 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.0923e-04 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9813e-05 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8661e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 4ms/step - loss: 8.5565e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.5502e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7662e-04 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 3ms/step - loss: 4.8352e-04 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4157e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.3622e-04 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1155e-04 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 3ms/step - loss: 9.5107e-05 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7162e-05 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5705e-04 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.6835e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.5886e-04 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4334e-05 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.4396e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.0830e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.2581e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4546e-04 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2950e-04 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6709e-05 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 3ms/step - loss: 1.9346e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 3ms/step - loss: 6.7789e-05 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.4215e-04 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.3719e-05 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.1939e-04 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 4ms/step - loss: 8.2674e-05 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 4ms/step - loss: 5.2313e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 2ms/step - loss: 1.7340e-04 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3406e-05 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 3ms/step - loss: 5.1099e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8021e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 4ms/step - loss: 3.5212e-05 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1903e-05 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8128e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.4898e-05 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 3ms/step - loss: 8.4453e-04 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6129e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 3ms/step - loss: 7.6941e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.8778e-04 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1029e-04 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 3ms/step - loss: 2.3514e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7078e-04 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 4ms/step - loss: 2.0042e-04 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 4ms/step - loss: 4.6678e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 3ms/step - loss: 3.4598e-05 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0033 - accuracy: 1.0000

# %%
def bag_of_words(msg, words):
    tokens = nltk.word_tokenize(msg)
    tokens = [lemmatizer.lemmatize(w.lower()) for w in tokens if w not in string.punctuation] 
    bow = [0] * len(words)
    for w in tokens:
        for idx, word in enumerate(words):
            if word == w:
                bow[idx] = 1
    return np.array(bow)        
def pred_class(text, vocab, labels): 
    bow = bag_of_words(text, vocab)
    result = model.predict(np.array([bow]))[0]
    thresh = 0.2
    y_pred = [[idx, res] for idx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in y_pred:
        return_list.append(labels[r[0]])
    return return_list

def get_response(intents_list, intents_json): 
    tags_ = intents_list[0]

    print(tags_)
    list_of_intents = intents_json["intents"]
    for i in list_of_intents: 
        if i["tag"] == tag:
            result = random.choice(i["responses"])
            break
    return result

# %%
while True:
    message = input('')
    intents = pred_class(message, words, tags)
    result = get_response(intents, data)
    print(result)
# Out:
# hello
# date
# Speak soon!
# bye
# greeting
# It was nice speaking to you
# bye
# greeting
# See you later
